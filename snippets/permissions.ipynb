# %% [markdown]
# # ProPyCore SDK Examples: Permissions
#
# This notebook contains snippets from the `permissions.py` module.

# %%
import os
import dotenv
import json

import ProPyCore

# %% [markdown]
# ## Setup
# You will need to create the connection to your Procore app and then get the details for your company and project.
#
# ### Connection to Procore App
# Ensure you have a `.env` file with the following information included:
# * `CLIENT_ID`: your data connection app's client ID
# * `CLIENT_SECRET`: your data connection app's client secret

# %%
dotenv.load_dotenv()
connection = ProPyCore.procore.Procore(
    client_id=os.getenv("CLIENT_ID"),
    client_secret=os.getenv("CLIENT_SECRET"),
    redirect_uri="urn:ietf:wg:oauth:2.0:oob", # default for data connection apps
    oauth_url="https://app.procore.com", # default for data connection apps
    base_url="https://app.procore.com" # default for data connection apps
)

# %%
COMPANY_ID=8089

# %% [markdown]
# ---

# %% [markdown]
# ### `permissions.get()`
# Gets all the available permissions from the [Get Permissions](https://developers.procore.com/reference/rest/permissions?version=latest) endpoint.
#
# ```python
# """
# Parameters
# ----------
# company_id : int
#     unique identifier for the company
# project_id : int, default None
#     unique identifier for the project
#     Include for project-level permissions
#
# Returns
# -------
# permissions : dict
#     available permissions
# """
# ```

# %%
# Company-level permissions
company_permissions = connection.permissions.get(
    company_id=COMPANY_ID
)
#print(json.dumps(company_permissions, indent=4))

# Project-level permissions
project = connection.projects.find(
    company_id=COMPANY_ID,
    identifier="VDC Department"
)
project_permissions = connection.permissions.get(
    company_id=COMPANY_ID,
    project_id=project["id"]
)
print(json.dumps(project_permissions, indent=4))
# Out:
# {
#     "tools": [
#         {
#             "available_for_user": true,
#             "domain_id": 1,
#             "friendly_name": "Correspondence",
#             "id": 174363917,
#             "name": "communication_types",
#             "permitted_actions": [],
#             "create_url": "",
#             "can_create": false,
#             "tab_group": "project_management",
#             "url": "https://app.procore.com/3133196/project/correspondence_types",
#             "user_access_level": {
#                 "id": 2,
#                 "name": "Read Only"
#             },
#             "trial": false
#         },
#         {
#             "available_for_user": true,
#             "domain_id": 1,
#             "friendly_name": "Home",
#             "id": 174363927,
#             "name": "home",
#             "permitted_actions": [],
#             "create_url": null,
#             "can_create": null,
#             "tab_group": "core",
#             "url": "/3133196/project/home",
#             "user_access_level": {
#                 "id": 4,
#                 "name": "Admin"
#             },
#             "trial": false
#         },
#         {
#             "available_for_user": true,
#             "domain_id": 80,
#             "friendly_name": "Change Events",
#             "id": 174363889,
#             "name": "change_events",
#             "permitted_actions": [],
#             "create_url": "/3133196/project/change_events/events/new",
#             "can_create": true,
#             "tab_group": "financials",
#             "url": "/3133196/project/change_events/events",
#             "user_access_level": {
#                 "id": 4,
#                 "name": "Admin"
#             },
#             "trial": false
#         },
#         {
#             "available_for_user": true,
#             "domain_id": 5,
#             "friendly_name": "Directory",
#             "id": 174363902,
#             "name": "directory",
#             "permitted_actions": [],
#             "create_url": null,
#             "can_create": null,
#             "tab_group": "core",
#             "url": "/3133196/project/directory",
#             "user_access_level": {
#                 "id": 4,
#                 "name": "Admin"
#             },
#             "trial": false
#         },
#         {
#             "available_for_user": true,
#             "domain_id": 91,
#             "friendly_name": "Timesheets",
#             "id": 174363947,
#             "name": "timesheets",
#             "permitted_actions": [],
#             "create_url": null,
#             "can_create": null,
#             "tab_group": "field_productivity",
#             "url": "/3133196/project/timesheets",
#             "user_access_level": {
#                 "id": 4,
#                 "name": "Admin"
#             },
#             "trial": false
#         },
#         {
#             "available_for_user": true,
#             "domain_id": 122,
#             "friendly_name": "Connection Manager",
#             "id": 174363895,
#             "name": "connection_hub",
#             "permitted_actions": [],
#             "create_url": null,
#             "can_create": null,
#             "tab_group": "core",
#             "url": "/3133196/project/connection_hub",
#             "user_access_level": {
#                 "id": 4,
#                 "name": "Admin"
#             },
#             "trial": false
#         },
#         {
#             "available_for_user": true,
#             "domain_id": 15,
#             "friendly_name": "Admin",
#             "id": 174363883,
#             "name": "admin",
#             "permitted_actions": [
#                 {
#                     "id": 67897532,
#                     "action_name": "create_wbs_codes",
#                     "tool_name": "admin",
#                     "label": "Create WBS Codes"
#                 }
#             ],
#             "create_url": null,
#             "can_create": null,
#             "tab_group": "core",
#             "url": "/3133196/project/admin",
#             "user_access_level": {
#                 "id": 4,
#                 "name": "Admin"
#             },
#             "trial": false
#         }
#     ]
# }

# %% [markdown]
# ### `permissions.get_company_templates()`
# ```python
# """
# Parameters
# ----------
# company_id : int
#     unique identifier for the company
#
# Returns
# -------
# company_templates : dict
#     available company templates
# """
# ```

# %%
company_permission_templates = connection.permissions.get_company_templates(company_id=COMPANY_ID)
print(json.dumps(company_permission_templates, indent=4))
# Out:
# [
#     {
#         "id": 909198,
#         "name": "Z - 212096 401 First Street SH Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 927952,
#         "name": "[RO] Field Engineering Leadership",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 985410,
#         "name": "Z - 221037 Lifepath Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1021331,
#         "name": "Z - 214036 300 Main Owner w/Punch",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1008583,
#         "name": "Z - 214034 S. Laredo Safety w/ Daily Log",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1003467,
#         "name": "Z - 212053 Waco Owners / CxAlloy",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1027028,
#         "name": "Z - 231047 BSW Grapevine Owners w/Punch",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 971028,
#         "name": "[RO] Project Coordinator",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 952716,
#         "name": "Z - 222025 BSW College Station MOB Subcontractors",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 757077,
#         "name": "[RO] People Services",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 50248,
#         "name": "[External] Architect/Engineer",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 1026833,
#         "name": "Z - 242037 Element Critical Owner w/RFI",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 873579,
#         "name": "[External] Architect/Engineer - Coord. Issues ON, Model ON",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 793854,
#         "name": "[External] Architect/Engineer - Coord. Issues ON, No Model Access",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 731093,
#         "name": "[External] Architect/Engineer - Drawing Upload",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 883153,
#         "name": "Z - 212023 Mueller Bravo Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 962882,
#         "name": "Z - 232010 St. Stephens Owner Rep",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1028621,
#         "name": "Z - 231067 BSW Irving Owners w/Punch",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 943832,
#         "name": "Z - 212008 MACC Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1009203,
#         "name": "Z - 232021 Hancock Development Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1009204,
#         "name": "Z - 232721 Hancock Early Work Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 50245,
#         "name": "[External] Owner/Client",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 1017464,
#         "name": "Z - 231089 Universal Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1024900,
#         "name": "Z - 241001 Databank Red Oak Subs w/Photo Access",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 711748,
#         "name": "[External] Subcontractor - BIM",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 997220,
#         "name": "Z - 232072 Starbase Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 956586,
#         "name": "Z - 231024 Ellis County Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1021721,
#         "name": "Z - 221073 - Healthpeak GC Partner",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1004625,
#         "name": "Z - 231068 Databank DFW8 Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1007266,
#         "name": "Z - 232039 TSTC Waco Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1011095,
#         "name": "Z - 212053 Waco HS Subs w/Photo Access",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1001807,
#         "name": "Z - 211003 Waco Marriott Owner Punch",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 768502,
#         "name": "[RO] Accounting - Financials",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 1024880,
#         "name": "Z - 232049 AISD Houston ES Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1021233,
#         "name": "Z - 243006 Amazon EV Hub Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1024357,
#         "name": "Z - 224007 Thomas Jefferson A/E",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1013781,
#         "name": "Z - 233011 Deer Park Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 1012840,
#         "name": "Z - 231070 Dallas Zoo Inspectors",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 682651,
#         "name": "[RO] Employee - View Only",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 927958,
#         "name": "[RO] Field Engineering",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 893212,
#         "name": "[RO] Preconstruction",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 773614,
#         "name": "[RO] Quality/MEP",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 853122,
#         "name": "[RO] Quality/MEP Leadership",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 689092,
#         "name": "[RO] Safety Manager",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 821450,
#         "name": "[RO] Scheduler",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 704562,
#         "name": "[RO] VDC",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 707669,
#         "name": "[RO] Project Admin",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 50584,
#         "name": "[RO] Ops - Quality Manager",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 774276,
#         "name": "[RO] Ops - Intern",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 720211,
#         "name": "[RO] Procore Power User",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 1025217,
#         "name": "Z - 241001 Databank Red Oak Owners",
#         "project_specific": true,
#         "type": "project_specific"
#     },
#     {
#         "id": 683889,
#         "name": "[RO] Accounting - Full Admin",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 689095,
#         "name": "[RO] Executive Team",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 952729,
#         "name": "[RO] R&D",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 50244,
#         "name": "[RO] Ops - Project Manager",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 50246,
#         "name": "[RO] Ops - Superintendent",
#         "project_specific": false,
#         "type": "global"
#     },
#     {
#         "id": 50247,
#         "name": "[External] Subcontractor",
#         "project_specific": false,
#         "type": "global"
#     }
# ]

# %% [markdown]
# ### `permissions.get_company_template()`
# ```python
# """
# Parameters
# ----------
# company_id : int
#     unique identifier for the company
# template_id : int
#     unique identifier for the template
#
# Returns
# -------
# company_template : dict
#     available company template
# """
# ```

# %%
ro_randd_template = connection.permissions.get_company_template(company_id=COMPANY_ID, template_id=952729)
print(json.dumps(ro_randd_template, indent=4))
# Out:
# ---------------------------------------------------------------------------
# NoPrivilegeError                          Traceback (most recent call last)
# File ~/Projects/ProPyCore/ProPyCore/access/permissions.py:93, in Permissions.get_company_template(self, company_id, template_id)
#      92 try:
# ---> 93     response = self.get_request(self.endpoint + f"/companies/{company_id}/permission_templates/{template_id}", additional_headers=headers)
#      94 except ProcoreException as e:
#
# File ~/Projects/ProPyCore/ProPyCore/access/base.py:63, in Base.get_request(self, api_url, additional_headers, params)
#      62 else:
# ---> 63     raise_exception(response)
#
# File ~/Projects/ProPyCore/ProPyCore/exceptions.py:74, in raise_exception(response)
#      73 elif response.status_code == 403:
# ---> 74     raise NoPrivilegeError(f"403: Data connection app or permission template does not have access to this endpoint", response.text)
#      76 elif response.status_code == 404:
#
# NoPrivilegeError: '403: Data connection app or permission template does not have access to this endpoint'
#
# During handling of the above exception, another exception occurred:
#
# WrongParamsError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ro_randd_template = connection.permissions.get_company_template(company_id=COMPANY_ID, template_id=952729)
#       2 print(json.dumps(ro_randd_template, indent=4))
#
# File ~/Projects/ProPyCore/ProPyCore/access/permissions.py:95, in Permissions.get_company_template(self, company_id, template_id)
#      93     response = self.get_request(self.endpoint + f"/companies/{company_id}/permission_templates/{template_id}", additional_headers=headers)
#      94 except ProcoreException as e:
# ---> 95     raise WrongParamsError(e)
#      97 return response
#
# WrongParamsError: NoPrivilegeError('403: Data connection app or permission template does not have access to this endpoint')

# %% [markdown]
# ### `permissions.get_project_templates()`
# ```python
# """
# Gets all the available project templates
#
# Parameters
# ----------
# company_id : int
#     unique identifier for the company
# project_id : int
#     unique identifier for the project
#
# Returns
# -------
# project_templates : dict
#     available project templates
# """
# ```

# %%
sandbox_project = connection.projects.find(
    company_id=COMPANY_ID,
    identifier="Sandbox Test Project"
)
project_permission_templates = connection.permissions.get_project_templates(company_id=COMPANY_ID, project_id=sandbox_project["id"])
print(json.dumps(project_permission_templates, indent=4))
# Out:
# []

# %% [markdown]
# ---
