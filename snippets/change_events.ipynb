# %% [markdown]
# # ProPyCore SDK Examples: Change Events
#
# This notebook contains snippets from the `change_events` module.

# %%
import os
import dotenv
import json

import ProPyCore

# %% [markdown]
# ## Setup
# You will need to create the connection to your Procore app and then get the details for your company and project.
#
# ### Connection to Procore App
# Ensure you have a `.env` file with the following information included:
# * `CLIENT_ID`: your data connection app's client ID
# * `CLIENT_SECRET`: your data connection app's client secret

# %%
dotenv.load_dotenv()
client = ProPyCore.procore.Procore(
    client_id=os.getenv("CLIENT_ID"),
    client_secret=os.getenv("CLIENT_SECRET"),
    redirect_uri="urn:ietf:wg:oauth:2.0:oob", # default for data connection apps
    oauth_url="https://app.procore.com", # default for data connection apps
    base_url="https://app.procore.com" # default for data connection apps
)

# %% [markdown]
# ### Get Company Details
# Use the cell below to specify your company name

# %%
companies = client.companies.get()
for company in companies:
    print(company["name"])

company_name = companies[0]["name"]
# Out:
# Rogers-O`Brien Construction

# %% [markdown]
# Now get the company details

# %%
COMPANY = client.companies.find(identifier=company_name)
projects = client.projects.get(company_id=COMPANY["id"])
PROJECT = client.projects.find(company_id=COMPANY["id"], identifier="OpX Test Project")

# %% [markdown]
# ### `change_events.get_statuses()`
# ```python
# """
# Gets all the available change event statuses
#
# Parameters
# ----------
# company_id : int
#     unique identifier for the company
# project_id : int
#     unique identifier for the project
#
# Returns
# -------
# change_event_statuses : dict
#     available change event statuses
# """
# ```

# %%
statuses = client.change_events.get_statuses(
    company_id=COMPANY["id"],
    project_id=PROJECT["id"],
)

print(json.dumps(statuses, indent=4))
# Out:
# [
#     {
#         "id": 31807,
#         "name": "Open",
#         "mapped_to_status": "open",
#         "show_in_select": true,
#         "default_status": false
#     },
#     {
#         "id": 31808,
#         "name": "Closed",
#         "mapped_to_status": "closed",
#         "show_in_select": true,
#         "default_status": false
#     },
#     {
#         "id": 31809,
#         "name": "Void",
#         "mapped_to_status": "void",
#         "show_in_select": true,
#         "default_status": false
#     },
#     {
#         "id": 31810,
#         "name": "Pending",
#         "mapped_to_status": "pending",
#         "show_in_select": true,
#         "default_status": false
#     },
#     {
#         "id": 528799,
#         "name": "Pco Submitted",
#         "mapped_to_status": "pending",
#         "show_in_select": true,
#         "default_status": false
#     }
# ]

# %% [markdown]
# ### `change_events.get()`
# ```python
# """
# Gets all the available change events
#
# Parameters
# ----------
# company_id : int
#     unique identifier for the company
# project_id : int
#     unique identifier for the project
# page : int, default 1
#     page number
# per_page : int, default 100
#     number of companies to include
#
# Returns
# -------
# change_events : dict
#     available change events data
# """
# ```

# %%
events = client.change_events.get(
    company_id=COMPANY["id"],
    project_id=PROJECT["id"],
    per_page=10000
)

print(f"Total Events: {len(events)}")
print(f"Event {events[0]['id']}: {events[0]['title']}")
print(json.dumps(events[0], indent=4))
# Out:
# Total Events: 15
# Event 10595542: Change all yellow walls to blue
# {
#     "created_at": "2023-10-27T18:39:10Z",
#     "description": "<p>Per owner walk</p>",
#     "event_scope": "out_of_scope",
#     "event_type": "Owner Change",
#     "id": 10595542,
#     "number": 15,
#     "alphanumeric_number": "015",
#     "project_id": 2261578,
#     "status": "open",
#     "title": "Change all yellow walls to blue",
#     "updated_at": "2024-10-22T14:35:16Z",
#     "change_event_line_items": [
#         {
#             "id": 27142015,
#             "biller": {
#                 "id": 2261578,
#                 "name": "OpX Test Project",
#                 "model_name": "Project",
#                 "guid": "Z2lkOi8vcHJvY29yZS9Qcm9qZWN0LzIyNjE1Nzg"
#             },
#             "biller_guid": "Z2lkOi8vcHJvY29yZS9Qcm9qZWN0LzIyNjE1Nzg",
#             "contract": {
#                 "id": 9310795,
#                 "number": "230011.103",
#                 "title": "Electrical",
#                 "name": "Electrical"
#             },
#             "cost_code": {
#                 "id": 750560579,
#                 "name": "Electrical LS",
#                 "full_code": "26-.10.99-",
#                 "origin_id": null,
#                 "origin_data": null,
#                 "standard_cost_code_id": 11796423,
#                 "biller": "OpX Test Project",
#                 "biller_id": 2261578,
#                 "biller_type": "Project",
#                 "biller_origin_id": null,
#                 "budgeted": true,
#                 "code": ".10.99-",
#                 "parent": {
#                     "id": 750560166
#                 },
#                 "sortable_code": "26-.10.99-",
#                 "created_at": "2022-10-07T15:31:55Z",
#                 "deleted_at": null,
#                 "line_item_types": [
#                     {
#                         "id": 832349,
#                         "name": "Other",
#                         "code": "O",
#                         "base_type": "other",
#                         "origin_id": "3593"
#                     },
#                     {
#                         "id": 832346,
#                         "name": "Subcontract",
#                         "code": "S",
#                         "base_type": "commitment",
#                         "origin_id": "3590"
#                     },
#                     {
#                         "id": 832345,
#                         "name": "Material-Unincorporated",
#                         "code": "MUN",
#                         "base_type": "materials",
#                         "origin_id": "3589"
#                     },
#                     {
#                         "id": 832344,
#                         "name": "Material-Incorporated",
#                         "code": "MIN",
#                         "base_type": "materials",
#                         "origin_id": "3588"
#                     }
#                 ],
#                 "position": null,
#                 "updated_at": "2022-10-07T15:31:55Z"
#             },
#             "cost_type": {
#                 "id": 832346,
#                 "provider_id": 8089,
#                 "provider_type": "Company",
#                 "name": "Subcontract",
#                 "csv_import_code": "S",
#                 "base_type": "commitment",
#                 "position": 20,
#                 "deleted_at": null,
#                 "created_at": "2020-04-24T20:25:23Z",
#                 "updated_at": "2020-04-24T20:25:23Z",
#                 "timesheet_type": true,
#                 "company_id": 8089,
#                 "equipment_timecard_entry_type": false
#             },
#             "cost_code_biller_name": "OpX Test Project",
#             "cost_code_id": 750560579,
#             "cost_code_is_budgeted": true,
#             "deletable": false,
#             "description": "remove outlets",
#             "editable": false,
#             "estimated_cost_amount": "1500.0",
#             "event_id": 10595542,
#             "line_item_type": {
#                 "id": 832346,
#                 "name": "Subcontract",
#                 "code": "S",
#                 "base_type": "commitment"
#             },
#             "line_item_type_id": 832346,
#             "links": {
#                 "edit": "https://app.procore.com/2261578/project/change_events/events/10595542/edit?celi_id=27142015#27142015",
#                 "view": "https://app.procore.com/2261578/project/change_events/events/10595542?celi_id=27142015#27142015",
#                 "parent": "https://app.procore.com/2261578/project/change_events/events/10595542?celi_id=27142015",
#                 "contract": "https://app.procore.com/2261578/project/commitments/work_order_contracts/9310795",
#                 "rfq_amount": "https://app.procore.com/2261578/project/commitments/work_order_contracts/9310795/request_for_quotes/1814141",
#                 "rom": "https://app.procore.com/2261578/project/change_events/events/10595542?celi_id=27142015#27142015",
#                 "prime_pco_cost": "https://app.procore.com/2261578/project/prime_contracts/9347901/change_orders/potential_change_orders/16791036?subtab=line_items"
#             },
#             "number": "015",
#             "permission_to_edit": null,
#             "proposed_contract_id": 9310795,
#             "proposed_vendor_id": 26505054,
#             "request_for_quote_id": 1814141,
#             "rfq_amount": "1000.0",
#             "rfq_amount_project_currency": "1000.0",
#             "rom": "1500.0",
#             "sortable_code": "26-.10.99- - Electrical LS",
#             "status": "Open",
#             "statuses": {
#                 "contract": "Approved",
#                 "rfq_amount": "Pending Final Approval",
#                 "rfq_tooltip": "RFQ #003: CE #015 - Change all yellow walls to blue, Pending Final Approval",
#                 "prime_pco_cost": "Draft",
#                 "prime_pco_tooltip": "PCO #502: CE #015 - Change all yellow wa, Draft"
#             },
#             "title": "Change all yellow walls to blue",
#             "vendor": {
#                 "id": 26505054,
#                 "name": "Electrical Test Company"
#             },
#             "event_title_and_number": "CE #015 - Change all yellow walls to blue",
#             "is_markup_summary": false,
#             "estimated_cost_calculation_strategy": "manual",
#             "estimated_cost_quantity": null,
#             "estimated_cost_unit_cost": null,
#             "uom": null,
#             "wbs_code": {
#                 "description": "Electrical LS.Subcontract",
#                 "flat_code": "26-.10.99-.S",
#                 "id": 488976965
#             },
#             "prime_pco_cost": "1000.0",
#             "prime_pco_cost_project_currency": "1000.0",
#             "latest_revenue_amount": "1000.0",
#             "latest_revenue_amount_project_currency": "1000.0",
#             "over_under_amount": "0.0",
#             "over_under_amount_project_currency": "0.0",
#             "revenue_rom_amount": "1000.0",
#             "revenue_rom_amount_project_currency": "1000.0",
#             "revenue_rom_display": "auto",
#             "revenue_rom_calculation_strategy": "manual",
#             "revenue_rom_quantity": "0.0",
#             "revenue_rom_uom": "ls",
#             "revenue_rom_unit_cost": "0.0",
#             "latest_cost_calculation_strategy": "manual",
#             "latest_cost_quantity": "0.0",
#             "latest_cost_uom": "ls",
#             "latest_cost_unit_cost": "0.0",
#             "non_committed_cost": null,
#             "manual_latest_cost_amount": null,
#             "latest_cost_amount": "1000.0",
#             "latest_cost_amount_project_currency": "1000.0"
#         },
#         {
#             "id": 27142016,
#             "biller": {
#                 "id": 2261578,
#                 "name": "OpX Test Project",
#                 "model_name": "Project",
#                 "guid": "Z2lkOi8vcHJvY29yZS9Qcm9qZWN0LzIyNjE1Nzg"
#             },
#             "biller_guid": "Z2lkOi8vcHJvY29yZS9Qcm9qZWN0LzIyNjE1Nzg",
#             "contract": {
#                 "id": 9325610,
#                 "number": "230011.104",
#                 "title": "Painting",
#                 "name": "Painting"
#             },
#             "cost_code": {
#                 "id": 750561625,
#                 "name": "Painting LS",
#                 "full_code": "09-.90.99-",
#                 "origin_id": null,
#                 "origin_data": null,
#                 "standard_cost_code_id": 11795455,
#                 "biller": "OpX Test Project",
#                 "biller_id": 2261578,
#                 "biller_type": "Project",
#                 "biller_origin_id": null,
#                 "budgeted": true,
#                 "code": ".90.99-",
#                 "parent": {
#                     "id": 750560176
#                 },
#                 "sortable_code": "09-.90.99-",
#                 "created_at": "2022-10-07T15:31:55Z",
#                 "deleted_at": null,
#                 "line_item_types": [
#                     {
#                         "id": 832349,
#                         "name": "Other",
#                         "code": "O",
#                         "base_type": "other",
#                         "origin_id": "3593"
#                     },
#                     {
#                         "id": 832346,
#                         "name": "Subcontract",
#                         "code": "S",
#                         "base_type": "commitment",
#                         "origin_id": "3590"
#                     },
#                     {
#                         "id": 832345,
#                         "name": "Material-Unincorporated",
#                         "code": "MUN",
#                         "base_type": "materials",
#                         "origin_id": "3589"
#                     },
#                     {
#                         "id": 832344,
#                         "name": "Material-Incorporated",
#                         "code": "MIN",
#                         "base_type": "materials",
#                         "origin_id": "3588"
#                     }
#                 ],
#                 "position": null,
#                 "updated_at": "2022-10-07T15:31:55Z"
#             },
#             "cost_type": {
#                 "id": 832346,
#                 "provider_id": 8089,
#                 "provider_type": "Company",
#                 "name": "Subcontract",
#                 "csv_import_code": "S",
#                 "base_type": "commitment",
#                 "position": 20,
#                 "deleted_at": null,
#                 "created_at": "2020-04-24T20:25:23Z",
#                 "updated_at": "2020-04-24T20:25:23Z",
#                 "timesheet_type": true,
#                 "company_id": 8089,
#                 "equipment_timecard_entry_type": false
#             },
#             "cost_code_biller_name": "OpX Test Project",
#             "cost_code_id": 750561625,
#             "cost_code_is_budgeted": true,
#             "deletable": false,
#             "description": "repaint walls",
#             "editable": false,
#             "estimated_cost_amount": "5000.0",
#             "event_id": 10595542,
#             "line_item_type": {
#                 "id": 832346,
#                 "name": "Subcontract",
#                 "code": "S",
#                 "base_type": "commitment"
#             },
#             "line_item_type_id": 832346,
#             "links": {
#                 "edit": "https://app.procore.com/2261578/project/change_events/events/10595542/edit?celi_id=27142016#27142016",
#                 "view": "https://app.procore.com/2261578/project/change_events/events/10595542?celi_id=27142016#27142016",
#                 "parent": "https://app.procore.com/2261578/project/change_events/events/10595542?celi_id=27142016",
#                 "contract": "https://app.procore.com/2261578/project/commitments/work_order_contracts/9325610",
#                 "rfq_amount": "https://app.procore.com/2261578/project/commitments/work_order_contracts/9325610/request_for_quotes/1814140",
#                 "rom": "https://app.procore.com/2261578/project/change_events/events/10595542?celi_id=27142016#27142016",
#                 "prime_pco_cost": "https://app.procore.com/2261578/project/prime_contracts/9347901/change_orders/potential_change_orders/16791036?subtab=line_items"
#             },
#             "number": "015",
#             "permission_to_edit": null,
#             "proposed_contract_id": 9325610,
#             "proposed_vendor_id": 26505057,
#             "request_for_quote_id": 1814140,
#             "rfq_amount": "750.0",
#             "rfq_amount_project_currency": "750.0",
#             "rom": "5000.0",
#             "sortable_code": "09-.90.99- - Painting LS",
#             "status": "Open",
#             "statuses": {
#                 "contract": "Approved",
#                 "rfq_amount": "Pending Final Approval",
#                 "rfq_tooltip": "RFQ #004: CE #015 - Change all yellow walls to blue, Pending Final Approval",
#                 "prime_pco_cost": "Draft",
#                 "prime_pco_tooltip": "PCO #502: CE #015 - Change all yellow wa, Draft"
#             },
#             "title": "Change all yellow walls to blue",
#             "vendor": {
#                 "id": 26505057,
#                 "name": "Paint Test Company"
#             },
#             "event_title_and_number": "CE #015 - Change all yellow walls to blue",
#             "is_markup_summary": false,
#             "estimated_cost_calculation_strategy": "manual",
#             "estimated_cost_quantity": null,
#             "estimated_cost_unit_cost": null,
#             "uom": null,
#             "wbs_code": {
#                 "description": "Painting LS.Subcontract",
#                 "flat_code": "09-.90.99-.S",
#                 "id": 488977113
#             },
#             "prime_pco_cost": "4500.0",
#             "prime_pco_cost_project_currency": "4500.0",
#             "latest_revenue_amount": "4500.0",
#             "latest_revenue_amount_project_currency": "4500.0",
#             "over_under_amount": "3750.0",
#             "over_under_amount_project_currency": "3750.0",
#             "revenue_rom_amount": "750.0",
#             "revenue_rom_amount_project_currency": "750.0",
#             "revenue_rom_display": "auto",
#             "revenue_rom_calculation_strategy": "manual",
#             "revenue_rom_quantity": "0.0",
#             "revenue_rom_uom": "ls",
#             "revenue_rom_unit_cost": "0.0",
#             "latest_cost_calculation_strategy": "manual",
#             "latest_cost_quantity": "0.0",
#             "latest_cost_uom": "ls",
#             "latest_cost_unit_cost": "0.0",
#             "non_committed_cost": null,
#             "manual_latest_cost_amount": null,
#             "latest_cost_amount": "750.0",
#             "latest_cost_amount_project_currency": "750.0"
#         }
#     ],
#     "change_order_change_reason": {
#         "id": 41542,
#         "company_id": 8089,
#         "change_reason": "Client Request"
#     },
#     "change_event_status": {
#         "id": 31807,
#         "name": "Open",
#         "mapped_to_status": "open",
#         "show_in_select": true,
#         "default_status": false
#     },
#     "created_by": {
#         "id": 6093824,
#         "login": "lwilliamson@r-o.com",
#         "name": "Lacey Williamson"
#     },
#     "attachments": [
#         {
#             "id": 4329735502,
#             "filename": "uber 24.02.pdf",
#             "name": "uber 24.02.pdf",
#             "url": "https://storage.procore.com/api/v5/files/us-east-1/pro-core.com/companies/9808/01HDS6VBTMK2RT3FJ19Z17106B?companyId=8089&projectId=2261578&sig=65ef4ed280621afdebe3a3f8bd69d7f7f952f1554e4765e1162de141ca915316"
#         }
#     ],
#     "rfqs": [
#         {
#             "id": 1814140,
#             "commitment_contract_id": 9325610,
#             "created_at": "2023-10-27T18:41:18Z",
#             "description": "<p><span style=\"text-decoration: underline;\">CE #015 - Change all yellow walls to blue</span></p>\r\n<p>Per owner walk</p>",
#             "due_date": "2023-10-30",
#             "estimated_status": "rom",
#             "intent_to_quote": true,
#             "number": "004",
#             "original_quote": "750.0",
#             "position": 4,
#             "private": false,
#             "prostore_file_ids": [
#                 4329735502
#             ],
#             "status": "pending_final_approval",
#             "title": "CE #015 - Change all yellow walls to blue",
#             "updated_at": "2024-01-23T17:00:04Z",
#             "quotes": [
#                 {
#                     "id": 1698571,
#                     "cost": "750.0",
#                     "created_at": "2024-01-23T16:59:13Z",
#                     "description": "",
#                     "prostore_file_ids": [],
#                     "schedule_impact": 0,
#                     "updated_at": "2024-01-23T16:59:13Z",
#                     "request_for_quote_id": 1814140,
#                     "created_by_id": 6093824,
#                     "created_by": {
#                         "id": 6093824,
#                         "login": "lwilliamson@r-o.com",
#                         "name": "Lacey Williamson"
#                     },
#                     "attachments": []
#                 }
#             ],
#             "responses": [
#                 {
#                     "id": 700912,
#                     "comment": "",
#                     "created_at": "2024-01-23T17:00:04Z",
#                     "prostore_file_ids": [],
#                     "updated_at": "2024-01-23T17:00:04Z",
#                     "created_by": {
#                         "id": 6093824,
#                         "login": "lwilliamson@r-o.com",
#                         "name": "Lacey Williamson"
#                     },
#                     "attachments": []
#                 }
#             ],
#             "change_event_line_item_id": 27142016,
#             "created_by": {
#                 "id": 6093824,
#                 "login": "lwilliamson@r-o.com",
#                 "name": "Lacey Williamson"
#             },
#             "attachments": [
#                 {
#                     "id": 4329735502,
#                     "filename": "uber 24.02.pdf",
#                     "name": "uber 24.02.pdf",
#                     "url": "https://storage.procore.com/api/v5/files/us-east-1/pro-core.com/companies/9808/01HDS6VBTMK2RT3FJ19Z17106B?companyId=8089&projectId=2261578&sig=65ef4ed280621afdebe3a3f8bd69d7f7f952f1554e4765e1162de141ca915316"
#                 }
#             ]
#         },
#         {
#             "id": 1814141,
#             "commitment_contract_id": 9310795,
#             "created_at": "2023-10-27T18:41:19Z",
#             "description": "<p><span style=\"text-decoration: underline;\">CE #015 - Change all yellow walls to blue</span></p>\r\n<p>Per owner walk</p>",
#             "due_date": "2023-10-30",
#             "estimated_status": "rom",
#             "intent_to_quote": true,
#             "number": "003",
#             "original_quote": "1000.0",
#             "position": 3,
#             "private": false,
#             "prostore_file_ids": [
#                 4329735502
#             ],
#             "status": "pending_final_approval",
#             "title": "CE #015 - Change all yellow walls to blue",
#             "updated_at": "2023-10-27T18:43:18Z",
#             "quotes": [
#                 {
#                     "id": 1638275,
#                     "cost": "1000.0",
#                     "created_at": "2023-10-27T18:42:47Z",
#                     "description": "",
#                     "prostore_file_ids": [
#                         4329751161
#                     ],
#                     "schedule_impact": 0,
#                     "updated_at": "2023-10-27T18:42:47Z",
#                     "request_for_quote_id": 1814141,
#                     "attachments_count": 1,
#                     "created_by_id": 6093824,
#                     "created_by": {
#                         "id": 6093824,
#                         "login": "lwilliamson@r-o.com",
#                         "name": "Lacey Williamson"
#                     },
#                     "attachments": [
#                         {
#                             "id": 4329751161,
#                             "filename": "PCO#098 - Covers T&M.pdf",
#                             "name": "PCO#098 - Covers T&M.pdf",
#                             "url": "https://storage.procore.com/api/v5/files/us-east-1/pro-core.com/companies/9808/01HDS74799TK7FZCM3JEKR7277?companyId=8089&projectId=2261578&sig=ec40efaa6e06d05d07ab0ec89654b6f23fa8779cefd3b0adeb34589fadc89eda"
#                         }
#                     ]
#                 }
#             ],
#             "responses": [
#                 {
#                     "id": 669185,
#                     "comment": "",
#                     "created_at": "2023-10-27T18:43:18Z",
#                     "prostore_file_ids": [],
#                     "updated_at": "2023-10-27T18:43:18Z",
#                     "created_by": {
#                         "id": 6093824,
#                         "login": "lwilliamson@r-o.com",
#                         "name": "Lacey Williamson"
#                     },
#                     "attachments": []
#                 }
#             ],
#             "change_event_line_item_id": 27142015,
#             "created_by": {
#                 "id": 6093824,
#                 "login": "lwilliamson@r-o.com",
#                 "name": "Lacey Williamson"
#             },
#             "attachments": [
#                 {
#                     "id": 4329735502,
#                     "filename": "uber 24.02.pdf",
#                     "name": "uber 24.02.pdf",
#                     "url": "https://storage.procore.com/api/v5/files/us-east-1/pro-core.com/companies/9808/01HDS6VBTMK2RT3FJ19Z17106B?companyId=8089&projectId=2261578&sig=65ef4ed280621afdebe3a3f8bd69d7f7f952f1554e4765e1162de141ca915316"
#                 }
#             ]
#         }
#     ]
# }

# %% [markdown]
# ### `change_events.show()`
# ```python
# """
# Shows the Change Event info.
#
# Parameters
# ----------
# company_id : int
#     unique identifier for the company
# project_id : int
#     unique identifier for the project
# event_id : int
#     unique identifier for the event
#
# Returns
# -------
# event_info : dict
#     specific event information
# """
# ```

# %%
# Find by ID
submittal1 = client.change_events.show(
    company_id=COMPANY["id"],
    project_id=PROJECT["id"],
    event_id=10595542
)

print(submittal1["title"])
# Out:
# Change all yellow walls to blue

# %% [markdown]
# ---
